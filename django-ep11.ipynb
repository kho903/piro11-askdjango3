# %%
## ForeignKey
Comment
# Out:
# blog.models.Comment

# %%
comment=Comment.objects.first()

# %%
from django.db import connection
connection.queries[-1]
# Out:
# {'sql': 'SELECT "blog_comment"."id", "blog_comment"."post_id", "blog_comment"."author", "blog_comment"."message", "blog_comment"."created_at", "blog_comment"."updated_at" FROM "blog_comment" ORDER BY "blog_comment"."id" ASC  LIMIT 1',
#  'time': '0.002'}

# %%
comment.post_id
# Out:
# 4

# %%
print(comment.post) #위에가 간편
print(Post.objects.get(id=comment.post_id))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\dev\askdjango\venv\lib\site-packages\django\db\models\fields\related_descriptors.py in __get__(self, instance, cls)
#     163         try:
# --> 164             rel_obj = self.field.get_cached_value(instance)
#     165         except KeyError:
#
# C:\dev\askdjango\venv\lib\site-packages\django\db\models\fields\mixins.py in get_cached_value(self, instance, default)
#      12         try:
# ---> 13             return instance._state.fields_cache[cache_name]
#      14         except KeyError:
#
# KeyError: 'post'
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# C:\dev\askdjango\venv\lib\site-packages\django\db\backends\utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83             else:
# ...

# %%
connection.queries[-1]
# Out:
# {'sql': 'SELECT "blog_post"."id", "blog_post"."author", "blog_post"."title", "blog_post"."content", "blog_post"."tags", "blog_post"."lnglat", "blog_post"."status", "blog_post"."created_at", "blog_post"."updated_at" FROM "blog_post" WHERE "blog_post"."id" = 4',
#  'time': '0.001'}

# %%
#ONeToOneField
Profile
# Out:
# accounts.models.Profile

# %%
profile=Profile.objects.first()

# %%
connection.queries[-1]
# Out:
# {'sql': 'SELECT "accounts_profile"."id", "accounts_profile"."user_id", "accounts_profile"."phone_number", "accounts_profile"."address" FROM "accounts_profile" ORDER BY "accounts_profile"."id" ASC  LIMIT 1',
#  'time': '0.001'}

# %%
profile.user_id
# Out:
# 1

# %%
profile.user
# Out:
# <User: kho903>

# %%
connection.queries[-1]
# Out:
# {'sql': 'SELECT "auth_user"."id", "auth_user"."password", "auth_user"."last_login", "auth_user"."is_superuser", "auth_user"."username", "auth_user"."first_name", "auth_user"."last_name", "auth_user"."email", "auth_user"."is_staff", "auth_user"."is_active", "auth_user"."date_joined" FROM "auth_user" WHERE "auth_user"."id" = 1',
#  'time': '0.001'}

# %%
Comment.objects.create(post=post, author='김지훈', message='댓글#3')
# Out:
# <Comment: Comment object (5)>

# %%
###related_name
post=Post.objects.first()
print(Comment.objects.filter(post=post)) #방법 1
print(post.comment_set.all()) #방법2 -related name
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\dev\askdjango\venv\lib\site-packages\django\db\backends\utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#
# C:\dev\askdjango\venv\lib\site-packages\django\db\backends\sqlite3\base.py in execute(self, query, params)
#     382         query = self.convert_query(query)
# --> 383         return Database.Cursor.execute(self, query, params)
#     384
#
# OperationalError: no such column: blog_post.author
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-52-6e2cf7e1bebf> in <module>
#       1 ###related_name
# ----> 2 post=Post.objects.first()
#       3 print(Comment.objects.filter(post=post)) #방법 1
# ...

# %%
comment=Comment.objects.first()
comment.post
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\dev\askdjango\venv\lib\site-packages\django\db\models\fields\related_descriptors.py in __get__(self, instance, cls)
#     163         try:
# --> 164             rel_obj = self.field.get_cached_value(instance)
#     165         except KeyError:
#
# C:\dev\askdjango\venv\lib\site-packages\django\db\models\fields\mixins.py in get_cached_value(self, instance, default)
#      12         try:
# ---> 13             return instance._state.fields_cache[cache_name]
#      14         except KeyError:
#
# KeyError: 'post'
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# C:\dev\askdjango\venv\lib\site-packages\django\db\backends\utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83             else:
# ...

# %%
user = User.objects.first()

# %%
user.post_set.all#filter(title__icontains="M")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-b1a3704065ce> in <module>
# ----> 1 user.post_set.all#filter(title__icontains="M")
#
# AttributeError: 'User' object has no attribute 'post_set'

# %%
### ManyToManyField
from blog.models import Post

post = Post.objects.first() 
tag1 = Tab.objects.all()[0]
tag2 = Tab.objects.all()[1]
tag3 = Tab.objects.all()[2]
tag_qs = Tab.objects.filter(name__endswith='django')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\dev\askdjango\venv\lib\site-packages\django\db\backends\utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#
# C:\dev\askdjango\venv\lib\site-packages\django\db\backends\sqlite3\base.py in execute(self, query, params)
#     382         query = self.convert_query(query)
# --> 383         return Database.Cursor.execute(self, query, params)
#     384
#
# OperationalError: no such column: blog_post.author
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-67-5f4981faeaa3> in <module>
#       2 from blog.models import Post
#       3
# ----> 4 post = Post.objects.first()
# ...

# %%
post.tag_set.add(*tag_qs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-62b416e663b9> in <module>
# ----> 1 post.tag_set.add(*tag_qs)
#
# NameError: name 'tag_qs' is not defined

# %%
post.tag_set.all()
# Out:
# <QuerySet [<Tag: django>]>
