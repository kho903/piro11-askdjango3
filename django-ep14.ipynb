# %%
from django.urls import reverse

# %%
reverse('blog:post_list')
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-56-15e85110adaf> in <module>
# ----> 1 reverse('blog:post_list')
#
# C:\dev\askdjango\venv\lib\site-packages\django\urls\base.py in reverse(viewname, urlconf, args, kwargs, current_app)
#      56             # Lookup the name to see if it could be an app identifier.
#      57             try:
# ---> 58                 app_list = resolver.app_dict[ns]
#      59                 # Yes! Path part matches an app in the current Resolver.
#      60                 if current_ns and current_ns in app_list:
#
# C:\dev\askdjango\venv\lib\site-packages\django\urls\resolvers.py in app_dict(self)
#     510         language_code = get_language()
#     511         if language_code not in self._app_dict:
# --> 512             self._populate()
#     513         return self._app_dict[language_code]
#     514
#
# ...

# %%
reverse('blog:post_detail', args=[10])
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-57-33927131ad8a> in <module>
# ----> 1 reverse('blog:post_detail', args=[10])
#
# C:\dev\askdjango\venv\lib\site-packages\django\urls\base.py in reverse(viewname, urlconf, args, kwargs, current_app)
#      56             # Lookup the name to see if it could be an app identifier.
#      57             try:
# ---> 58                 app_list = resolver.app_dict[ns]
#      59                 # Yes! Path part matches an app in the current Resolver.
#      60                 if current_ns and current_ns in app_list:
#
# C:\dev\askdjango\venv\lib\site-packages\django\urls\resolvers.py in app_dict(self)
#     510         language_code = get_language()
#     511         if language_code not in self._app_dict:
# --> 512             self._populate()
#     513         return self._app_dict[language_code]
#     514
#
# ...

# %%
reverse('blog:post_detail', kwargs=['id':10])
# Out:
#   File "<ipython-input-58-d0a4e4cbc1df>", line 1
#     reverse('blog:post_detail', kwargs=['id':10])
#                                             ^
# SyntaxError: invalid syntax

# %%
reverse('blog:post_detail', 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\dev\askdjango\venv\lib\site-packages\django\urls\resolvers.py in url_patterns(self)
#     580         try:
# --> 581             iter(patterns)
#     582         except TypeError:
#
# TypeError: 'int' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-59-cc7918fddc8d> in <module>
# ----> 1 reverse('blog:post_detail', 10)
#
# C:\dev\askdjango\venv\lib\site-packages\django\urls\base.py in reverse(viewname, urlconf, args, kwargs, current_app)
#      56             # Lookup the name to see if it could be an app identifier.
#      57             try:
# ---> 58                 app_list = resolver.app_dict[ns]
#      59                 # Yes! Path part matches an app in the current Resolver.
# ...

# %%
reverse('blog:post_detail', 'id':10)
# Out:
#   File "<ipython-input-60-2991f61f76b8>", line 1
#     reverse('blog:post_detail', 'id':10)
#                                     ^
# SyntaxError: invalid syntax
