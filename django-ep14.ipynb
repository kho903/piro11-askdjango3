# %%
from django.urls import reverse

# %%
reverse('blog:post_list')
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-10-15e85110adaf> in <module>
# ----> 1 reverse('blog:post_list')
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\base.py in reverse(viewname, urlconf, args, kwargs, current_app)
#      28     if urlconf is None:
#      29         urlconf = get_urlconf()
# ---> 30     resolver = get_resolver(urlconf)
#      31     args = args or []
#      32     kwargs = kwargs or {}
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\resolvers.py in get_resolver(urlconf)
#      66 def get_resolver(urlconf=None):
#      67     if urlconf is None:
# ---> 68         urlconf = settings.ROOT_URLCONF
#      69     return URLResolver(RegexPattern(r'^/'), urlconf)
#      70
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      77         """Return the value of a setting and cache it in self.__dict__."""
#      78         if self._wrapped is empty:
# ---> 79             self._setup(name)
#      80         val = getattr(self._wrapped, name)
#      81         self.__dict__[name] = val
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      62                 "You must either define the environment variable %s "
#      63                 "or call settings.configure() before accessing settings."
# ---> 64                 % (desc, ENVIRONMENT_VARIABLE))
#      65
#      66         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting ROOT_URLCONF, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.

# %%
reverse('blog:post_detail', args=[10])
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-11-33927131ad8a> in <module>
# ----> 1 reverse('blog:post_detail', args=[10])
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\base.py in reverse(viewname, urlconf, args, kwargs, current_app)
#      28     if urlconf is None:
#      29         urlconf = get_urlconf()
# ---> 30     resolver = get_resolver(urlconf)
#      31     args = args or []
#      32     kwargs = kwargs or {}
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\resolvers.py in get_resolver(urlconf)
#      66 def get_resolver(urlconf=None):
#      67     if urlconf is None:
# ---> 68         urlconf = settings.ROOT_URLCONF
#      69     return URLResolver(RegexPattern(r'^/'), urlconf)
#      70
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      77         """Return the value of a setting and cache it in self.__dict__."""
#      78         if self._wrapped is empty:
# ---> 79             self._setup(name)
#      80         val = getattr(self._wrapped, name)
#      81         self.__dict__[name] = val
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      62                 "You must either define the environment variable %s "
#      63                 "or call settings.configure() before accessing settings."
# ---> 64                 % (desc, ENVIRONMENT_VARIABLE))
#      65
#      66         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting ROOT_URLCONF, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.

# %%
reverse('blog:post_detail', kwargs={'id':10})
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-13-dc257b2d44df> in <module>
# ----> 1 reverse('blog:post_detail', kwargs={'id':10})
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\base.py in reverse(viewname, urlconf, args, kwargs, current_app)
#      28     if urlconf is None:
#      29         urlconf = get_urlconf()
# ---> 30     resolver = get_resolver(urlconf)
#      31     args = args or []
#      32     kwargs = kwargs or {}
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\resolvers.py in get_resolver(urlconf)
#      66 def get_resolver(urlconf=None):
#      67     if urlconf is None:
# ---> 68         urlconf = settings.ROOT_URLCONF
#      69     return URLResolver(RegexPattern(r'^/'), urlconf)
#      70
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      77         """Return the value of a setting and cache it in self.__dict__."""
#      78         if self._wrapped is empty:
# ---> 79             self._setup(name)
#      80         val = getattr(self._wrapped, name)
#      81         self.__dict__[name] = val
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      62                 "You must either define the environment variable %s "
#      63                 "or call settings.configure() before accessing settings."
# ---> 64                 % (desc, ENVIRONMENT_VARIABLE))
#      65
#      66         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting ROOT_URLCONF, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.

# %%
from django.shortcuts import resolve_url

# %%
reverse('blog:post_list')
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-16-15e85110adaf> in <module>
# ----> 1 reverse('blog:post_list')
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\base.py in reverse(viewname, urlconf, args, kwargs, current_app)
#      28     if urlconf is None:
#      29         urlconf = get_urlconf()
# ---> 30     resolver = get_resolver(urlconf)
#      31     args = args or []
#      32     kwargs = kwargs or {}
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\resolvers.py in get_resolver(urlconf)
#      66 def get_resolver(urlconf=None):
#      67     if urlconf is None:
# ---> 68         urlconf = settings.ROOT_URLCONF
#      69     return URLResolver(RegexPattern(r'^/'), urlconf)
#      70
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      77         """Return the value of a setting and cache it in self.__dict__."""
#      78         if self._wrapped is empty:
# ---> 79             self._setup(name)
#      80         val = getattr(self._wrapped, name)
#      81         self.__dict__[name] = val
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      62                 "You must either define the environment variable %s "
#      63                 "or call settings.configure() before accessing settings."
# ---> 64                 % (desc, ENVIRONMENT_VARIABLE))
#      65
#      66         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting ROOT_URLCONF, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.

# %%
resolve_url('blog:post_detail',10)
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-17-f928524ab30f> in <module>
# ----> 1 resolve_url('blog:post_detail',10)
#
# c:\dev\askdjango\venv\lib\site-packages\django\shortcuts.py in resolve_url(to, *args, **kwargs)
#     146     # Next try a reverse URL resolution.
#     147     try:
# --> 148         return reverse(to, args=args, kwargs=kwargs)
#     149     except NoReverseMatch:
#     150         # If this is a callable, re-raise.
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\base.py in reverse(viewname, urlconf, args, kwargs, current_app)
#      28     if urlconf is None:
#      29         urlconf = get_urlconf()
# ---> 30     resolver = get_resolver(urlconf)
#      31     args = args or []
#      32     kwargs = kwargs or {}
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\resolvers.py in get_resolver(urlconf)
#      66 def get_resolver(urlconf=None):
#      67     if urlconf is None:
# ---> 68         urlconf = settings.ROOT_URLCONF
#      69     return URLResolver(RegexPattern(r'^/'), urlconf)
#      70
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      77         """Return the value of a setting and cache it in self.__dict__."""
#      78         if self._wrapped is empty:
# ---> 79             self._setup(name)
#      80         val = getattr(self._wrapped, name)
#      81         self.__dict__[name] = val
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      62                 "You must either define the environment variable %s "
#      63                 "or call settings.configure() before accessing settings."
# ---> 64                 % (desc, ENVIRONMENT_VARIABLE))
#      65
#      66         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting ROOT_URLCONF, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.

# %%
resolve_url('blog:post_detail', id=10)
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-18-7033a2f2ca93> in <module>
# ----> 1 resolve_url('blog:post_detail', id=10)
#
# c:\dev\askdjango\venv\lib\site-packages\django\shortcuts.py in resolve_url(to, *args, **kwargs)
#     146     # Next try a reverse URL resolution.
#     147     try:
# --> 148         return reverse(to, args=args, kwargs=kwargs)
#     149     except NoReverseMatch:
#     150         # If this is a callable, re-raise.
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\base.py in reverse(viewname, urlconf, args, kwargs, current_app)
#      28     if urlconf is None:
#      29         urlconf = get_urlconf()
# ---> 30     resolver = get_resolver(urlconf)
#      31     args = args or []
#      32     kwargs = kwargs or {}
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\resolvers.py in get_resolver(urlconf)
#      66 def get_resolver(urlconf=None):
#      67     if urlconf is None:
# ---> 68         urlconf = settings.ROOT_URLCONF
#      69     return URLResolver(RegexPattern(r'^/'), urlconf)
#      70
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      77         """Return the value of a setting and cache it in self.__dict__."""
#      78         if self._wrapped is empty:
# ---> 79             self._setup(name)
#      80         val = getattr(self._wrapped, name)
#      81         self.__dict__[name] = val
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      62                 "You must either define the environment variable %s "
#      63                 "or call settings.configure() before accessing settings."
# ---> 64                 % (desc, ENVIRONMENT_VARIABLE))
#      65
#      66         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting ROOT_URLCONF, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.

# %%
resolve_url('/hello/')
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-19-ee916fab6a10> in <module>
# ----> 1 resolve_url('/hello/')
#
# c:\dev\askdjango\venv\lib\site-packages\django\shortcuts.py in resolve_url(to, *args, **kwargs)
#     146     # Next try a reverse URL resolution.
#     147     try:
# --> 148         return reverse(to, args=args, kwargs=kwargs)
#     149     except NoReverseMatch:
#     150         # If this is a callable, re-raise.
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\base.py in reverse(viewname, urlconf, args, kwargs, current_app)
#      28     if urlconf is None:
#      29         urlconf = get_urlconf()
# ---> 30     resolver = get_resolver(urlconf)
#      31     args = args or []
#      32     kwargs = kwargs or {}
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\resolvers.py in get_resolver(urlconf)
#      66 def get_resolver(urlconf=None):
#      67     if urlconf is None:
# ---> 68         urlconf = settings.ROOT_URLCONF
#      69     return URLResolver(RegexPattern(r'^/'), urlconf)
#      70
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      77         """Return the value of a setting and cache it in self.__dict__."""
#      78         if self._wrapped is empty:
# ---> 79             self._setup(name)
#      80         val = getattr(self._wrapped, name)
#      81         self.__dict__[name] = val
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      62                 "You must either define the environment variable %s "
#      63                 "or call settings.configure() before accessing settings."
# ---> 64                 % (desc, ENVIRONMENT_VARIABLE))
#      65
#      66         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting ROOT_URLCONF, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.

# %%
from django.shortcuts import redirect

# %%
redirect('blog:post_detail',10)
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-25-eefca1898383> in <module>
# ----> 1 redirect('blog:post_detail',10)
#
# c:\dev\askdjango\venv\lib\site-packages\django\shortcuts.py in redirect(to, permanent, *args, **kwargs)
#      56     """
#      57     redirect_class = HttpResponsePermanentRedirect if permanent else HttpResponseRedirect
# ---> 58     return redirect_class(resolve_url(to, *args, **kwargs))
#      59
#      60
#
# c:\dev\askdjango\venv\lib\site-packages\django\shortcuts.py in resolve_url(to, *args, **kwargs)
#     146     # Next try a reverse URL resolution.
#     147     try:
# --> 148         return reverse(to, args=args, kwargs=kwargs)
#     149     except NoReverseMatch:
#     150         # If this is a callable, re-raise.
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\base.py in reverse(viewname, urlconf, args, kwargs, current_app)
#      28     if urlconf is None:
#      29         urlconf = get_urlconf()
# ---> 30     resolver = get_resolver(urlconf)
#      31     args = args or []
#      32     kwargs = kwargs or {}
#
# c:\dev\askdjango\venv\lib\site-packages\django\urls\resolvers.py in get_resolver(urlconf)
#      66 def get_resolver(urlconf=None):
#      67     if urlconf is None:
# ---> 68         urlconf = settings.ROOT_URLCONF
#      69     return URLResolver(RegexPattern(r'^/'), urlconf)
#      70
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      77         """Return the value of a setting and cache it in self.__dict__."""
#      78         if self._wrapped is empty:
# ---> 79             self._setup(name)
#      80         val = getattr(self._wrapped, name)
#      81         self.__dict__[name] = val
#
# c:\dev\askdjango\venv\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      62                 "You must either define the environment variable %s "
#      63                 "or call settings.configure() before accessing settings."
# ---> 64                 % (desc, ENVIRONMENT_VARIABLE))
#      65
#      66         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting ROOT_URLCONF, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
